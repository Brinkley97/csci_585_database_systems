# %%
import numpy as np

# %%
R=6
r=1
a=8
t = 0
curve = 12*np.pi
curve

# tt_coords = (,)
# Out:
# 37.69911184307752

# %%
# for t in range(0, curve, 0.01):
#     x[t] = (R+r)*np.cos((r/R)*t) - a*np.cos((1+r/R)*t)
#     y[t] = (R+r)*sin((r/R)*t) - a*sin((1+r/R)*t)

# %%
x_coords = []
y_coords = []
while t < curve:
    # print(t)
    x = (R+r)*np.cos((r/R)*t) - a*np.cos((1+r/R)*t) - 118.28538
    x_coords.append(x)
    y = (R+r)*np.sin((r/R)*t) - a*np.sin((1+r/R)*t) + 34.0205
    y_coords.append(y)
    t = t + 0.01

# %%
x_coords
# Out:
# [-119.28538,
#  -119.28484528395092,
#  -119.28324120987989,
#  -119.28056800000562,
#  -119.27682602465892,
#  -119.27201580223233,
#  -119.26613799910959,
#  -119.25919342957482,
#  -119.2511830557017,
#  -119.24210798722247,
#  -119.23196948137681,
#  -119.22076894274068,
#  -119.20850792303506,
#  -119.19518812091466,
#  -119.1808113817367,
#  -119.16537969730955,
#  -119.14889520562159,
#  -119.1313601905501,
#  -119.11277708155028,
#  -119.09314845332446,
#  -119.07247702547153,
#  -119.05076566211666,
#  -119.02801737152133,
#  -119.00423530567366,
#  -118.97942275985932,
#  -118.95358317221286,
#  -118.92672012324945,
#  -118.89883733537754,
#  -118.86993867239185,
#  -118.84002813894743,
#  -118.80910988001428,
#  -118.777188180313,
#  -118.74426746373145,
#  -118.71035229272229,
#  -118.67544736768188,
#  -118.63955752631016,
#  -118.60268774295204,
#  -118.56484312792004,
#  -118.52602892679852,
#  -118.48625051972938,
#  -118.44551342067957,
#  -118.40382327669029,
# ...

# %%
y_coords
# Out:
# [34.0205,
#  33.93883544520164,
#  33.85718356126733,
#  33.775557017332154,
#  33.693968479073575,
#  33.61243060698312,
#  33.53095605463891,
#  33.449557466979,
#  33.36824747857605,
#  33.28703871191323,
#  33.20594377566192,
#  33.124975262961186,
#  33.04414574969944,
#  32.96346779279841,
#  32.88295392849971,
#  32.80261667065422,
#  32.72246850901448,
#  32.642521907530444,
#  32.562789302648675,
#  32.48328310161528,
#  32.404015680782884,
#  32.32499938392178,
#  32.24624652053544,
#  32.16776936418084,
#  32.08958015079353,
#  32.01169107701791,
#  31.934114298542834,
#  31.856861928442797,
#  31.779946035524887,
#  31.703378642681812,
#  31.627171725251134,
#  31.551337209381014,
#  31.47588697040262,
#  31.400832831209463,
#  31.326186560643887,
#  31.251959871890893,
#  31.178164420879547,
#  31.10481180469219,
#  31.031913559981643,
#  30.95948116139665,
#  30.887526020015752,
#  30.81605948178982,
#  30.74509282599346,
#  30.67463726368547,
#  30.6047039361786,
# ...
